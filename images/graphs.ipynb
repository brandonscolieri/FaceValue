# %%
import numpy as np
import pandas as pd
import sys
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
col_names = ['epochs', 'time', 'loss', 'acc', 'val_loss', 'val_acc']

# df_worst is for the poster only
df_worst = pd.read_csv('worst_model.csv', delimiter=',', names=col_names)
df_second_best = pd.read_csv('second_best_model.csv', delimiter=',', names=col_names)
df_best = pd.read_csv('best_models_points_to_plot.csv', delimiter=',', names=col_names)
# df_final is for the final report only
df_final = pd.read_csv('latest.csv', delimiter=',', names=col_names)

# Remove columns that are useless
worst = df_worst.drop(df_worst.index[0])
second_worst = df_second_best.drop(df_second_best.index[0])
best = df_best.drop([df_best.index[0], df_best.index[-1]])
final = df_final.drop([df_final.index[0], df_final.index[-1]])

# %%
# Helper function to change strings in columns to numeric datatypes

def _numeric_helper(dataframe, cols_to_change):
    for i in cols_to_change:
        dataframe[i] = pd.to_numeric(dataframe[i])
    return dataframe

# %%
# Cast to proper types
datatype_dict = {'epochs': np.uint8, 'loss': np.float64, 'acc': np.float64, 'val_loss': np.float64, 'val_acc': np.float64}

df_w = _numeric_helper(worst, datatype_dict)
df_2w = _numeric_helper(second_worst, datatype_dict)
df_b = _numeric_helper(best, datatype_dict)
df_f = _numeric_helper(final, datatype_dict)

# %%
# # Helper function

# def _helper(dataframe, cols):
#     return (dataframe.loc[:, col].to_numpy() for col in cols)

# %% [markdown]
# ## Plots for worst model (POSTER)

# %%
# epochs_worst, _, loss_worst, acc_worst, val_loss_worst, val_acc_worst = _helper(worst, col_names)
# plt.axes()
# plt.yticks(np.arange(0, 4, step=0.2))
# plt.plot(epochs_worst, loss_worst, label='training')
# plt.plot(epochs_worst, val_loss_worst, label='validation')
# plt.xlabel('epochs')
# plt.ylabel('loss')
# plt.title('Loss of worst model')
# plt.legend()
# plt.show()
sns.lineplot(x='epochs', y='loss', data=df_w)
plt.title('Training loss for worst model')
plt.show()
sns.lineplot(x='epochs', y='val_loss', data=df_w)
plt.title('Validation loss for worst model')
plt.show()

# %%
# plt.plot(epochs_worst, acc_worst, label='training')
# plt.plot(epochs_worst, val_acc_worst, label='validation')
# plt.xlabel('epochs')
# plt.ylabel('accuracy')
# plt.title('Accuracies of worst model')
# plt.legend()
# plt.show()

gr = sns.lineplot(x='epochs', y='acc', data=df_w)
plt.title('Training accuracy for worst model')
plt.show()
gr = sns.lineplot(x='epochs', y='val_acc', data=df_w)
plt.title('Validation accuracy for worst model')
plt.show()

# %% [markdown]
# ## Plots for second-worst model (POSTER)
#
# This corresponds to iteration 1 in the final report.

# %%
sns.lineplot(x='epochs', y='loss', data=df_2w)
plt.title('Training loss for second worst model')
plt.show()
sns.lineplot(x='epochs', y='val_loss', data=df_2w)
plt.title('Validation loss for second worst model')
plt.show()

# %%
sns.lineplot(x='epochs', y='acc', data=df_2w)
plt.title('Training accuracy for second worst model')
plt.show()
sns.lineplot(x='epochs', y='val_acc', data=df_2w)
plt.title('Validation accuracy for second worst model')
plt.show()

# %% [markdown]
# ## Plots for best model (POSTER)
#
# This corresponds to iteration 2 in the final report.

# %%
sns.lineplot(x='epochs', y='loss', data=df_b)
plt.title('Training loss for best model')
plt.show()
sns.lineplot(x='epochs', y='val_loss', data=df_b)
plt.title('Validation loss for best model')
plt.show()

# %%
sns.lineplot(x='epochs', y='acc', data=df_b)
plt.title('Training accuracy for best model')
plt.show()
sns.lineplot(x='epochs', y='val_acc', data=df_b)
plt.title('Validation accuracy for best model')
plt.show()

# %% [markdown]
# ## Aggregate plots for all models (POSTER)
#
# Once again, models 2 and 3 here respectively correspond to iterations 1 and 2 in the final report.

# %%
# labels used in legend
legend_lb = ('Training Loss', 'Validation Loss', 'Training Accuracy', 'Validation Accuracy')

# %%
sns.set_palette("bright")

plt.plot('epochs', 'loss', data=df_w)
plt.plot('epochs', 'val_loss', data=df_w)
plt.plot('epochs', 'acc', data=df_w)
plt.plot('epochs', 'val_acc', data=df_w)
plt.title('Model 1 Accuracy and Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy / Loss')
plt.legend(labels=legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model_1", quality=95, dpi=1200, bbox_inches="tight")

# MAY NOT WORK PROPERLY! This shows the plot but it may not look good
plt.show()

# %%
sns.set_palette("bright")

plt.plot('epochs', 'loss', data=df_2w)
plt.plot('epochs', 'val_loss', data=df_2w)
plt.plot('epochs', 'acc', data=df_2w)
plt.plot('epochs', 'val_acc', data=df_2w)
plt.title('Model 2 Accuracy and Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy / Loss')
plt.legend(labels=legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.tight_layout(rect=[0,0,1.25,1])
plt.savefig("model_2", quality=95, dpi=1200, bbox_inches="tight")

# MAY NOT WORK PROPERLY! Running in jupyter notebook is OK; but not in regular python!
plt.show()

# %%
sns.set_palette("bright")

plt.plot('epochs', 'loss', data=df_b)
plt.plot('epochs', 'val_loss', data=df_b)
plt.plot('epochs', 'acc', data=df_b)
plt.plot('epochs', 'val_acc', data=df_b)
plt.title('Model 3 Accuracy and Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy / Loss')
plt.legend(labels=legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model_3", quality=95, dpi=1200, bbox_inches="tight")

# MAY NOT WORK PROPERLY! Running in jupyter notebook is OK; but not in regular python!
plt.show()

# %% [markdown]
# ## Accuracy plots for all models (POSTER, final report)
#
# **Do note that the plots of models 1-3 here correspond to the poster, but the code for models 2 and 3 also save images for the final report (where the models correspond to iterations 1 and 2, respectively.)** Also note that the plot for iteration 3 in the final report is titled "Final Model Accuracy" to avoid confusion with the plot for model 3. However, the image saved does not have this title.

# %%
# labels used in legend
acc_legend_lb = legend_lb[2:]

# %%
# For the poster only
sns.set_palette("bright")

plt.plot('epochs', 'acc', data=df_w)
plt.plot('epochs', 'val_acc', data=df_w)
plt.title('Model 1 Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(labels=acc_legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model_1_acc", quality=95, dpi=1200, bbox_inches="tight")

# MAY NOT WORK PROPERLY! This shows the plot but it may not look good
plt.show()

# %%
sns.set_palette("bright")

plt.plot('epochs', 'acc', data=df_2w)
plt.plot('epochs', 'val_acc', data=df_2w)
plt.title('Model 2 Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(labels=acc_legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.tight_layout(rect=[0,0,1.25,1])
plt.savefig("model_2_acc", quality=95, dpi=1200, bbox_inches="tight")

### FOR THE FINAL REPORT ###
plt.title('Model 1 Accuracy')
plt.savefig("model-iteration1", quality=95, dpi=1200, bbox_inches="tight")

### Reset title
plt.title('Model 2 Accuracy')

# MAY NOT WORK PROPERLY! Running in jupyter notebook is OK; but not in regular python!
plt.show()

# %%
sns.set_palette("bright")

plt.plot('epochs', 'acc', data=df_b)
plt.plot('epochs', 'val_acc', data=df_b)
plt.title('Model 3 Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(labels=acc_legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model_3_acc", quality=95, dpi=1200, bbox_inches="tight")

### FOR THE FINAL REPORT ###
plt.title('Model 2 Accuracy')
plt.savefig("model-iteration2", quality=95, dpi=1200, bbox_inches="tight")

### Reset title
plt.title('Model 3 Accuracy')

# MAY NOT WORK PROPERLY! Running in jupyter notebook is OK; but not in regular python!
plt.show()

# %%
# For the final report only
sns.set_palette("bright")

plt.plot('epochs', 'acc', data=df_f)
plt.plot('epochs', 'val_acc', data=df_f)

plt.title('Model 3 Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(labels=acc_legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model-iteration3", quality=95, dpi=1200, bbox_inches="tight")

### Change title
plt.title('Final Model Accuracy')

# MAY NOT WORK PROPERLY! Running in jupyter notebook is OK; but not in regular python!
plt.show()

# %% [markdown]
# ## Loss plots for all models (POSTER, final report)
#
# **Do note that the plots of models 1-3 here correspond to the poster, but the code for models 2 and 3 also save images for the final report (where the models correspond to iterations 1 and 2, respectively.)** Also note that the plot for iteration 3 in the final report is titled "Final Model Loss" to avoid confusion with the plot for model 3. However, the image saved does not have this title.

# %%
# Labels used in legend
loss_legend_lb = legend_lb[:2]

# %%
# For the poster only
sns.set_palette("bright")

plt.plot('epochs', 'loss', data=df_w)
plt.plot('epochs', 'val_loss', data=df_w)
plt.title('Model 1 Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(labels=loss_legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model_1_loss", quality=95, dpi=1200, bbox_inches="tight")

# MAY NOT WORK PROPERLY! This shows the plot but it may not look good
plt.show()

# %%
sns.set_palette("bright")

plt.plot('epochs', 'loss', data=df_2w)
plt.plot('epochs', 'val_loss', data=df_2w)
plt.title('Model 2 Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(labels=loss_legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model_2_loss", quality=95, dpi=1200, bbox_inches="tight")

### FOR THE FINAL REPORT ###
plt.title('Model 1 Loss')
plt.savefig("model-iteration1-loss", quality=95, dpi=1200, bbox_inches="tight")

### Reset title
plt.title('Model 2 Loss')

# MAY NOT WORK PROPERLY! This shows the plot but it may not look good
plt.show()

# %%
sns.set_palette("bright")

plt.plot('epochs', 'loss', data=df_b)
plt.plot('epochs', 'val_loss', data=df_b)
plt.title('Model 3 Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(labels=loss_legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model_3_loss", quality=95, dpi=1200, bbox_inches="tight")

### FOR THE FINAL REPORT ###
plt.title('Model 2 Loss')
plt.savefig("model-iteration2-loss", quality=95, dpi=1200, bbox_inches="tight")

### Reset title
plt.title('Model 3 Loss')

# MAY NOT WORK PROPERLY! This shows the plot but it may not look good
plt.show()

# %%
# For the final report only
sns.set_palette("bright")

plt.plot('epochs', 'loss', data=df_b)
plt.plot('epochs', 'val_loss', data=df_b)
plt.title('Model 3 Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(labels=loss_legend_lb, loc=5, bbox_to_anchor=(1.45, 0.5))
plt.savefig("model-iteration3-loss", quality=95, dpi=1200, bbox_inches="tight")

### Change title
plt.title('Final Model Loss')

# MAY NOT WORK PROPERLY! This shows the plot but it may not look good
plt.show()
